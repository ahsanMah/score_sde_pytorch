# %%
# %load_ext autoreload
# %autoreload 2
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import numpy as np
from torchinfo import summary
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from models.ncsnpp import *
from configs.subvp import cifar10_ncsnpp_continuous as configs
config = configs.get_config()
config
# Out:
# data:
#   centered: true
#   dataset: CIFAR10
#   image_size: 32
#   num_channels: 3
#   random_flip: true
#   uniform_dequantization: false
# device: !!python/object/apply:torch.device
# - cuda
# - 0
# eval:
#   batch_size: 1024
#   begin_ckpt: 9
#   bpd_dataset: test
#   enable_bpd: false
#   enable_loss: true
#   enable_sampling: false
#   end_ckpt: 26
#   num_samples: 50000
# model:
#   attention_type: ddpm
#   attn_resolutions: !!python/tuple
#   - 16
#   beta_max: 20.0
#   beta_min: 0.1
#   ch_mult: !!python/tuple
#   - 1
#   - 2
#   - 2
#   - 2
#   conditional: true
#   conv_size: 3
#   dropout: 0.1
#   ema_rate: 0.9999
#   embedding_type: positional
#   fir: true
#   fir_kernel:
#   - 1
#   - 3
#   - 3
#   - 1
#   fourier_scale: 16
#   init_scale: 0.0
#   name: ncsnpp
#   nf: 128
#   nonlinearity: swish
#   normalization: GroupNorm
#   num_res_blocks: 4
#   num_scales: 1000
#   progressive: none
#   progressive_combine: sum
#   progressive_input: residual
#   resamp_with_conv: true
#   resblock_type: biggan
#   scale_by_sigma: false
#   sigma_max: 50
#   sigma_min: 0.01
#   skip_rescale: true
# optim:
#   beta1: 0.9
#   eps: 1.0e-08
#   grad_clip: 1.0
#   lr: 0.0002
#   optimizer: Adam
#   warmup: 5000
#   weight_decay: 0
# sampling:
#   corrector: none
#   method: pc
#   n_steps_each: 1
#   noise_removal: true
#   predictor: euler_maruyama
#   probability_flow: false
#   snr: 0.16
# seed: 42
# training:
#   batch_size: 16
#   continuous: true
#   eval_freq: 100
#   likelihood_weighting: false
#   log_freq: 50
#   n_iters: 1300001
#   reduce_mean: true
#   sde: subvpsde
#   snapshot_freq: 50000
#   snapshot_freq_for_preemption: 10000
#   snapshot_sampling: true

# %%
import losses, sde_lib

sde = sde_lib.subVPSDE(
            beta_min=config.model.beta_min,
            beta_max=config.model.beta_max,
            N=config.model.num_scales,
        )

loss_fn = losses.get_sde_loss_fn(
    sde,
    train=True,
    reduce_mean=True,
    continuous=True,
    likelihood_weighting=False,
    eps=1e-5,
    masked_marginals=False,
)

# %%
model = NCSNpp(config)
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# NCSNpp                                   --
# ├─SiLU: 1-1                              --
# ├─ModuleList: 1-2                        --
# │    └─Linear: 2-1                       66,048
# │    └─Linear: 2-2                       262,656
# │    └─Conv2d: 2-3                       3,584
# │    └─ResnetBlockBigGANpp: 2-4          --
# │    │    └─GroupNorm: 3-1               256
# │    │    └─Conv2d: 3-2                  147,584
# │    │    └─Linear: 3-3                  65,664
# │    │    └─GroupNorm: 3-4               256
# │    │    └─Dropout: 3-5                 --
# │    │    └─Conv2d: 3-6                  147,584
# │    │    └─SiLU: 3-7                    --
# │    └─ResnetBlockBigGANpp: 2-5          --
# │    │    └─GroupNorm: 3-8               256
# │    │    └─Conv2d: 3-9                  147,584
# │    │    └─Linear: 3-10                 65,664
# │    │    └─GroupNorm: 3-11              256
# │    │    └─Dropout: 3-12                --
# │    │    └─Conv2d: 3-13                 147,584
# │    │    └─SiLU: 3-14                   --
# │    └─ResnetBlockBigGANpp: 2-6          --
# │    │    └─GroupNorm: 3-15              256
# │    │    └─Conv2d: 3-16                 147,584
# │    │    └─Linear: 3-17                 65,664
# │    │    └─GroupNorm: 3-18              256
# │    │    └─Dropout: 3-19                --
# │    │    └─Conv2d: 3-20                 147,584
# │    │    └─SiLU: 3-21                   --
# │    └─ResnetBlockBigGANpp: 2-7          --
# │    │    └─GroupNorm: 3-22              256
# │    │    └─Conv2d: 3-23                 147,584
# │    │    └─Linear: 3-24                 65,664
# │    │    └─GroupNorm: 3-25              256
# │    │    └─Dropout: 3-26                --
# │    │    └─Conv2d: 3-27                 147,584
# │    │    └─SiLU: 3-28                   --
# │    └─ResnetBlockBigGANpp: 2-8          --
# │    │    └─GroupNorm: 3-29              256
# │    │    └─Conv2d: 3-30                 147,584
# │    │    └─Linear: 3-31                 65,664
# │    │    └─GroupNorm: 3-32              256
# │    │    └─Dropout: 3-33                --
# │    │    └─Conv2d: 3-34                 147,584
# │    │    └─Conv2d: 3-35                 16,512
# │    │    └─SiLU: 3-36                   --
# │    └─Downsample: 2-9                   --
# │    │    └─Conv2d: 3-37                 3,584
# │    └─ResnetBlockBigGANpp: 2-10         --
# │    │    └─GroupNorm: 3-38              256
# │    │    └─Conv2d: 3-39                 295,168
# │    │    └─Linear: 3-40                 131,328
# │    │    └─GroupNorm: 3-41              512
# │    │    └─Dropout: 3-42                --
# │    │    └─Conv2d: 3-43                 590,080
# │    │    └─Conv2d: 3-44                 33,024
# │    │    └─SiLU: 3-45                   --
# │    └─AttnBlockpp: 2-11                 --
# │    │    └─GroupNorm: 3-46              512
# │    │    └─NIN: 3-47                    65,792
# │    │    └─NIN: 3-48                    65,792
# │    │    └─NIN: 3-49                    65,792
# │    │    └─NIN: 3-50                    65,792
# │    └─ResnetBlockBigGANpp: 2-12         --
# │    │    └─GroupNorm: 3-51              512
# │    │    └─Conv2d: 3-52                 590,080
# │    │    └─Linear: 3-53                 131,328
# │    │    └─GroupNorm: 3-54              512
# │    │    └─Dropout: 3-55                --
# │    │    └─Conv2d: 3-56                 590,080
# │    │    └─SiLU: 3-57                   --
# │    └─AttnBlockpp: 2-13                 --
# │    │    └─GroupNorm: 3-58              512
# │    │    └─NIN: 3-59                    65,792
# │    │    └─NIN: 3-60                    65,792
# │    │    └─NIN: 3-61                    65,792
# │    │    └─NIN: 3-62                    65,792
# │    └─ResnetBlockBigGANpp: 2-14         --
# │    │    └─GroupNorm: 3-63              512
# │    │    └─Conv2d: 3-64                 590,080
# │    │    └─Linear: 3-65                 131,328
# │    │    └─GroupNorm: 3-66              512
# │    │    └─Dropout: 3-67                --
# │    │    └─Conv2d: 3-68                 590,080
# │    │    └─SiLU: 3-69                   --
# │    └─AttnBlockpp: 2-15                 --
# │    │    └─GroupNorm: 3-70              512
# │    │    └─NIN: 3-71                    65,792
# │    │    └─NIN: 3-72                    65,792
# │    │    └─NIN: 3-73                    65,792
# │    │    └─NIN: 3-74                    65,792
# │    └─ResnetBlockBigGANpp: 2-16         --
# │    │    └─GroupNorm: 3-75              512
# │    │    └─Conv2d: 3-76                 590,080
# │    │    └─Linear: 3-77                 131,328
# │    │    └─GroupNorm: 3-78              512
# │    │    └─Dropout: 3-79                --
# │    │    └─Conv2d: 3-80                 590,080
# │    │    └─SiLU: 3-81                   --
# │    └─AttnBlockpp: 2-17                 --
# │    │    └─GroupNorm: 3-82              512
# │    │    └─NIN: 3-83                    65,792
# │    │    └─NIN: 3-84                    65,792
# │    │    └─NIN: 3-85                    65,792
# │    │    └─NIN: 3-86                    65,792
# │    └─ResnetBlockBigGANpp: 2-18         --
# │    │    └─GroupNorm: 3-87              512
# │    │    └─Conv2d: 3-88                 590,080
# │    │    └─Linear: 3-89                 131,328
# │    │    └─GroupNorm: 3-90              512
# │    │    └─Dropout: 3-91                --
# │    │    └─Conv2d: 3-92                 590,080
# │    │    └─Conv2d: 3-93                 65,792
# │    │    └─SiLU: 3-94                   --
# │    └─Downsample: 2-19                  --
# │    │    └─Conv2d: 3-95                 295,168
# │    └─ResnetBlockBigGANpp: 2-20         --
# │    │    └─GroupNorm: 3-96              512
# │    │    └─Conv2d: 3-97                 590,080
# │    │    └─Linear: 3-98                 131,328
# │    │    └─GroupNorm: 3-99              512
# │    │    └─Dropout: 3-100               --
# │    │    └─Conv2d: 3-101                590,080
# │    │    └─SiLU: 3-102                  --
# │    └─ResnetBlockBigGANpp: 2-21         --
# │    │    └─GroupNorm: 3-103             512
# │    │    └─Conv2d: 3-104                590,080
# │    │    └─Linear: 3-105                131,328
# │    │    └─GroupNorm: 3-106             512
# │    │    └─Dropout: 3-107               --
# │    │    └─Conv2d: 3-108                590,080
# │    │    └─SiLU: 3-109                  --
# │    └─ResnetBlockBigGANpp: 2-22         --
# │    │    └─GroupNorm: 3-110             512
# │    │    └─Conv2d: 3-111                590,080
# │    │    └─Linear: 3-112                131,328
# │    │    └─GroupNorm: 3-113             512
# │    │    └─Dropout: 3-114               --
# │    │    └─Conv2d: 3-115                590,080
# │    │    └─SiLU: 3-116                  --
# │    └─ResnetBlockBigGANpp: 2-23         --
# │    │    └─GroupNorm: 3-117             512
# │    │    └─Conv2d: 3-118                590,080
# │    │    └─Linear: 3-119                131,328
# │    │    └─GroupNorm: 3-120             512
# │    │    └─Dropout: 3-121               --
# │    │    └─Conv2d: 3-122                590,080
# │    │    └─SiLU: 3-123                  --
# │    └─ResnetBlockBigGANpp: 2-24         --
# │    │    └─GroupNorm: 3-124             512
# │    │    └─Conv2d: 3-125                590,080
# │    │    └─Linear: 3-126                131,328
# │    │    └─GroupNorm: 3-127             512
# │    │    └─Dropout: 3-128               --
# │    │    └─Conv2d: 3-129                590,080
# │    │    └─Conv2d: 3-130                65,792
# │    │    └─SiLU: 3-131                  --
# │    └─Downsample: 2-25                  --
# │    │    └─Conv2d: 3-132                590,080
# │    └─ResnetBlockBigGANpp: 2-26         --
# │    │    └─GroupNorm: 3-133             512
# │    │    └─Conv2d: 3-134                590,080
# │    │    └─Linear: 3-135                131,328
# │    │    └─GroupNorm: 3-136             512
# │    │    └─Dropout: 3-137               --
# │    │    └─Conv2d: 3-138                590,080
# │    │    └─SiLU: 3-139                  --
# │    └─ResnetBlockBigGANpp: 2-27         --
# │    │    └─GroupNorm: 3-140             512
# │    │    └─Conv2d: 3-141                590,080
# │    │    └─Linear: 3-142                131,328
# │    │    └─GroupNorm: 3-143             512
# │    │    └─Dropout: 3-144               --
# │    │    └─Conv2d: 3-145                590,080
# │    │    └─SiLU: 3-146                  --
# │    └─ResnetBlockBigGANpp: 2-28         --
# │    │    └─GroupNorm: 3-147             512
# │    │    └─Conv2d: 3-148                590,080
# │    │    └─Linear: 3-149                131,328
# │    │    └─GroupNorm: 3-150             512
# │    │    └─Dropout: 3-151               --
# │    │    └─Conv2d: 3-152                590,080
# │    │    └─SiLU: 3-153                  --
# │    └─ResnetBlockBigGANpp: 2-29         --
# │    │    └─GroupNorm: 3-154             512
# │    │    └─Conv2d: 3-155                590,080
# │    │    └─Linear: 3-156                131,328
# │    │    └─GroupNorm: 3-157             512
# │    │    └─Dropout: 3-158               --
# │    │    └─Conv2d: 3-159                590,080
# │    │    └─SiLU: 3-160                  --
# │    └─ResnetBlockBigGANpp: 2-30         --
# │    │    └─GroupNorm: 3-161             512
# │    │    └─Conv2d: 3-162                590,080
# │    │    └─Linear: 3-163                131,328
# │    │    └─GroupNorm: 3-164             512
# │    │    └─Dropout: 3-165               --
# │    │    └─Conv2d: 3-166                590,080
# │    │    └─SiLU: 3-167                  --
# │    └─AttnBlockpp: 2-31                 --
# │    │    └─GroupNorm: 3-168             512
# │    │    └─NIN: 3-169                   65,792
# │    │    └─NIN: 3-170                   65,792
# │    │    └─NIN: 3-171                   65,792
# │    │    └─NIN: 3-172                   65,792
# │    └─ResnetBlockBigGANpp: 2-32         --
# │    │    └─GroupNorm: 3-173             512
# │    │    └─Conv2d: 3-174                590,080
# │    │    └─Linear: 3-175                131,328
# │    │    └─GroupNorm: 3-176             512
# │    │    └─Dropout: 3-177               --
# │    │    └─Conv2d: 3-178                590,080
# │    │    └─SiLU: 3-179                  --
# │    └─ResnetBlockBigGANpp: 2-33         --
# │    │    └─GroupNorm: 3-180             1,024
# │    │    └─Conv2d: 3-181                1,179,904
# │    │    └─Linear: 3-182                131,328
# │    │    └─GroupNorm: 3-183             512
# │    │    └─Dropout: 3-184               --
# │    │    └─Conv2d: 3-185                590,080
# │    │    └─Conv2d: 3-186                131,328
# │    │    └─SiLU: 3-187                  --
# │    └─ResnetBlockBigGANpp: 2-34         --
# │    │    └─GroupNorm: 3-188             1,024
# │    │    └─Conv2d: 3-189                1,179,904
# │    │    └─Linear: 3-190                131,328
# │    │    └─GroupNorm: 3-191             512
# │    │    └─Dropout: 3-192               --
# │    │    └─Conv2d: 3-193                590,080
# │    │    └─Conv2d: 3-194                131,328
# │    │    └─SiLU: 3-195                  --
# │    └─ResnetBlockBigGANpp: 2-35         --
# │    │    └─GroupNorm: 3-196             1,024
# │    │    └─Conv2d: 3-197                1,179,904
# │    │    └─Linear: 3-198                131,328
# │    │    └─GroupNorm: 3-199             512
# │    │    └─Dropout: 3-200               --
# │    │    └─Conv2d: 3-201                590,080
# │    │    └─Conv2d: 3-202                131,328
# │    │    └─SiLU: 3-203                  --
# │    └─ResnetBlockBigGANpp: 2-36         --
# │    │    └─GroupNorm: 3-204             1,024
# │    │    └─Conv2d: 3-205                1,179,904
# │    │    └─Linear: 3-206                131,328
# │    │    └─GroupNorm: 3-207             512
# │    │    └─Dropout: 3-208               --
# │    │    └─Conv2d: 3-209                590,080
# │    │    └─Conv2d: 3-210                131,328
# │    │    └─SiLU: 3-211                  --
# │    └─ResnetBlockBigGANpp: 2-37         --
# │    │    └─GroupNorm: 3-212             1,024
# │    │    └─Conv2d: 3-213                1,179,904
# │    │    └─Linear: 3-214                131,328
# │    │    └─GroupNorm: 3-215             512
# │    │    └─Dropout: 3-216               --
# │    │    └─Conv2d: 3-217                590,080
# │    │    └─Conv2d: 3-218                131,328
# │    │    └─SiLU: 3-219                  --
# │    └─ResnetBlockBigGANpp: 2-38         --
# │    │    └─GroupNorm: 3-220             512
# │    │    └─Conv2d: 3-221                590,080
# │    │    └─Linear: 3-222                131,328
# │    │    └─GroupNorm: 3-223             512
# │    │    └─Dropout: 3-224               --
# │    │    └─Conv2d: 3-225                590,080
# │    │    └─Conv2d: 3-226                65,792
# │    │    └─SiLU: 3-227                  --
# │    └─ResnetBlockBigGANpp: 2-39         --
# │    │    └─GroupNorm: 3-228             1,024
# │    │    └─Conv2d: 3-229                1,179,904
# │    │    └─Linear: 3-230                131,328
# │    │    └─GroupNorm: 3-231             512
# │    │    └─Dropout: 3-232               --
# │    │    └─Conv2d: 3-233                590,080
# │    │    └─Conv2d: 3-234                131,328
# │    │    └─SiLU: 3-235                  --
# │    └─ResnetBlockBigGANpp: 2-40         --
# │    │    └─GroupNorm: 3-236             1,024
# │    │    └─Conv2d: 3-237                1,179,904
# │    │    └─Linear: 3-238                131,328
# │    │    └─GroupNorm: 3-239             512
# │    │    └─Dropout: 3-240               --
# │    │    └─Conv2d: 3-241                590,080
# │    │    └─Conv2d: 3-242                131,328
# │    │    └─SiLU: 3-243                  --
# │    └─ResnetBlockBigGANpp: 2-41         --
# │    │    └─GroupNorm: 3-244             1,024
# │    │    └─Conv2d: 3-245                1,179,904
# │    │    └─Linear: 3-246                131,328
# │    │    └─GroupNorm: 3-247             512
# │    │    └─Dropout: 3-248               --
# │    │    └─Conv2d: 3-249                590,080
# │    │    └─Conv2d: 3-250                131,328
# │    │    └─SiLU: 3-251                  --
# │    └─ResnetBlockBigGANpp: 2-42         --
# │    │    └─GroupNorm: 3-252             1,024
# │    │    └─Conv2d: 3-253                1,179,904
# │    │    └─Linear: 3-254                131,328
# │    │    └─GroupNorm: 3-255             512
# │    │    └─Dropout: 3-256               --
# │    │    └─Conv2d: 3-257                590,080
# │    │    └─Conv2d: 3-258                131,328
# │    │    └─SiLU: 3-259                  --
# │    └─ResnetBlockBigGANpp: 2-43         --
# │    │    └─GroupNorm: 3-260             1,024
# │    │    └─Conv2d: 3-261                1,179,904
# │    │    └─Linear: 3-262                131,328
# │    │    └─GroupNorm: 3-263             512
# │    │    └─Dropout: 3-264               --
# │    │    └─Conv2d: 3-265                590,080
# │    │    └─Conv2d: 3-266                131,328
# │    │    └─SiLU: 3-267                  --
# │    └─ResnetBlockBigGANpp: 2-44         --
# │    │    └─GroupNorm: 3-268             512
# │    │    └─Conv2d: 3-269                590,080
# │    │    └─Linear: 3-270                131,328
# │    │    └─GroupNorm: 3-271             512
# │    │    └─Dropout: 3-272               --
# │    │    └─Conv2d: 3-273                590,080
# │    │    └─Conv2d: 3-274                65,792
# │    │    └─SiLU: 3-275                  --
# │    └─ResnetBlockBigGANpp: 2-45         --
# │    │    └─GroupNorm: 3-276             1,024
# │    │    └─Conv2d: 3-277                1,179,904
# │    │    └─Linear: 3-278                131,328
# │    │    └─GroupNorm: 3-279             512
# │    │    └─Dropout: 3-280               --
# │    │    └─Conv2d: 3-281                590,080
# │    │    └─Conv2d: 3-282                131,328
# │    │    └─SiLU: 3-283                  --
# │    └─ResnetBlockBigGANpp: 2-46         --
# │    │    └─GroupNorm: 3-284             1,024
# │    │    └─Conv2d: 3-285                1,179,904
# │    │    └─Linear: 3-286                131,328
# │    │    └─GroupNorm: 3-287             512
# │    │    └─Dropout: 3-288               --
# │    │    └─Conv2d: 3-289                590,080
# │    │    └─Conv2d: 3-290                131,328
# │    │    └─SiLU: 3-291                  --
# │    └─ResnetBlockBigGANpp: 2-47         --
# │    │    └─GroupNorm: 3-292             1,024
# │    │    └─Conv2d: 3-293                1,179,904
# │    │    └─Linear: 3-294                131,328
# │    │    └─GroupNorm: 3-295             512
# │    │    └─Dropout: 3-296               --
# │    │    └─Conv2d: 3-297                590,080
# │    │    └─Conv2d: 3-298                131,328
# │    │    └─SiLU: 3-299                  --
# │    └─ResnetBlockBigGANpp: 2-48         --
# │    │    └─GroupNorm: 3-300             1,024
# │    │    └─Conv2d: 3-301                1,179,904
# │    │    └─Linear: 3-302                131,328
# │    │    └─GroupNorm: 3-303             512
# │    │    └─Dropout: 3-304               --
# │    │    └─Conv2d: 3-305                590,080
# │    │    └─Conv2d: 3-306                131,328
# │    │    └─SiLU: 3-307                  --
# │    └─ResnetBlockBigGANpp: 2-49         --
# │    │    └─GroupNorm: 3-308             768
# │    │    └─Conv2d: 3-309                884,992
# │    │    └─Linear: 3-310                131,328
# │    │    └─GroupNorm: 3-311             512
# │    │    └─Dropout: 3-312               --
# │    │    └─Conv2d: 3-313                590,080
# │    │    └─Conv2d: 3-314                98,560
# │    │    └─SiLU: 3-315                  --
# │    └─AttnBlockpp: 2-50                 --
# │    │    └─GroupNorm: 3-316             512
# │    │    └─NIN: 3-317                   65,792
# │    │    └─NIN: 3-318                   65,792
# │    │    └─NIN: 3-319                   65,792
# │    │    └─NIN: 3-320                   65,792
# │    └─ResnetBlockBigGANpp: 2-51         --
# │    │    └─GroupNorm: 3-321             512
# │    │    └─Conv2d: 3-322                590,080
# │    │    └─Linear: 3-323                131,328
# │    │    └─GroupNorm: 3-324             512
# │    │    └─Dropout: 3-325               --
# │    │    └─Conv2d: 3-326                590,080
# │    │    └─Conv2d: 3-327                65,792
# │    │    └─SiLU: 3-328                  --
# │    └─ResnetBlockBigGANpp: 2-52         --
# │    │    └─GroupNorm: 3-329             768
# │    │    └─Conv2d: 3-330                442,496
# │    │    └─Linear: 3-331                65,664
# │    │    └─GroupNorm: 3-332             256
# │    │    └─Dropout: 3-333               --
# │    │    └─Conv2d: 3-334                147,584
# │    │    └─Conv2d: 3-335                49,280
# │    │    └─SiLU: 3-336                  --
# │    └─ResnetBlockBigGANpp: 2-53         --
# │    │    └─GroupNorm: 3-337             512
# │    │    └─Conv2d: 3-338                295,040
# │    │    └─Linear: 3-339                65,664
# │    │    └─GroupNorm: 3-340             256
# │    │    └─Dropout: 3-341               --
# │    │    └─Conv2d: 3-342                147,584
# │    │    └─Conv2d: 3-343                32,896
# │    │    └─SiLU: 3-344                  --
# │    └─ResnetBlockBigGANpp: 2-54         --
# │    │    └─GroupNorm: 3-345             512
# │    │    └─Conv2d: 3-346                295,040
# │    │    └─Linear: 3-347                65,664
# │    │    └─GroupNorm: 3-348             256
# │    │    └─Dropout: 3-349               --
# │    │    └─Conv2d: 3-350                147,584
# │    │    └─Conv2d: 3-351                32,896
# │    │    └─SiLU: 3-352                  --
# │    └─ResnetBlockBigGANpp: 2-55         --
# │    │    └─GroupNorm: 3-353             512
# │    │    └─Conv2d: 3-354                295,040
# │    │    └─Linear: 3-355                65,664
# │    │    └─GroupNorm: 3-356             256
# │    │    └─Dropout: 3-357               --
# │    │    └─Conv2d: 3-358                147,584
# │    │    └─Conv2d: 3-359                32,896
# │    │    └─SiLU: 3-360                  --
# │    └─ResnetBlockBigGANpp: 2-56         --
# │    │    └─GroupNorm: 3-361             512
# │    │    └─Conv2d: 3-362                295,040
# │    │    └─Linear: 3-363                65,664
# │    │    └─GroupNorm: 3-364             256
# │    │    └─Dropout: 3-365               --
# │    │    └─Conv2d: 3-366                147,584
# │    │    └─Conv2d: 3-367                32,896
# │    │    └─SiLU: 3-368                  --
# │    └─GroupNorm: 2-57                   256
# │    └─Conv2d: 2-58                      3,459
# =================================================================
# Total params: 62,693,251
# Trainable params: 62,693,251
# Non-trainable params: 0
# =================================================================

# %%
x_dummy = torch.zeros(5,3,8,8)
t = torch.ones(x_dummy.shape[0])

# %%
model(x_dummy, t)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-11-f6abb4060f2a> in <module>
# ----> 1 model(x_dummy, t)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /home/score_sde_pytorch/models/ncsnpp.py in forward(self, x, time_cond)
#     335             # Residual blocks for this resolution
#     336             for i_block in range(self.num_res_blocks):
# --> 337                 h = modules[m_idx](hs[-1], temb)
#     338                 m_idx += 1
#     339                 if h.shape[-1] in self.attn_resolutions:
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: forward() takes 2 positional arguments but 3 were given

# %%
loss = loss_fn(model, x_dummy)
loss
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-10-c32baff0ceb1> in <module>
# ----> 1 loss = loss_fn(model, x_dummy)
#       2 loss
#
# /home/score_sde_pytorch/losses.py in loss_fn(model, batch)
#     123             perturbed_data = mean + std[:, None, None, None] * z
#     124
# --> 125         score = score_fn(perturbed_data, t)
#     126
#     127         if not likelihood_weighting:
#
# /home/score_sde_pytorch/models/utils.py in score_fn(x, t)
#     157                 # continuously-trained models.
#     158                 labels = t * 999
# --> 159                 score = model_fn(x, labels)
#     160                 std = sde.marginal_prob(torch.zeros_like(x), t)[1]
#     161             else:
#
# /home/score_sde_pytorch/models/utils.py in model_fn(x, labels)
#     129         else:
#     130             model.train()
# --> 131             return model(x, labels)
#     132
#     133     return model_fn
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /home/score_sde_pytorch/models/ncsnpp.py in forward(self, x, time_cond)
#     335             # Residual blocks for this resolution
#     336             for i_block in range(self.num_res_blocks):
# --> 337                 h = modules[m_idx](hs[-1], temb)
#     338                 m_idx += 1
#     339                 if h.shape[-1] in self.attn_resolutions:
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: forward() takes 2 positional arguments but 3 were given

# %%
from models import utils as mutils
train=True
reduce_mean=True
continuous=True
likelihood_weighting=True
eps=1e-5

reduce_op = (
    torch.mean
    if reduce_mean
    else lambda *args, **kwargs: 0.5 * torch.sum(*args, **kwargs)
)

def loss_fn(model, batch):
        """Compute the loss function.

        Args:
          model: A score model.
          batch: A mini-batch of training data.

        Returns:
          loss: A scalar that represents the average loss value across the mini-batch.
        """
        score_fn = mutils.get_score_fn(sde, model, train=train, continuous=continuous)
        t = torch.zeros(batch.shape[0], device=batch.device) * (sde.T - eps) + eps

        z = torch.zeros_like(batch)
        mean, std = sde.marginal_prob(batch, t)
        perturbed_data = mean + sde._unsqueeze(std) * z

        score = score_fn(perturbed_data, t)

        if not likelihood_weighting:
            losses = torch.square(score * sde._unsqueeze(std) + z)
            losses = reduce_op(losses.reshape(losses.shape[0], -1), dim=-1)
        else:
            g2 = sde.sde(torch.zeros_like(batch), t)[1] ** 2
            losses = torch.square(score + z / sde._unsqueeze(std))
            losses = reduce_op(losses.reshape(losses.shape[0], -1), dim=-1) * g2

        loss = torch.mean(losses)
        return loss

# %%
mg_model.load_state_dict(unParalled_state_dict, strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['init_conv.weight', 'init_conv.bias', 'init_pool.weight', 'init_pool.bias', 'down_tr64.dense.weight', 'down_tr64.dense.bias', 'down_tr128.dense.weight', 'down_tr128.dense.bias', 'down_tr256.dense.weight', 'down_tr256.dense.bias', 'down_tr512.dense.weight', 'down_tr512.dense.bias', 'up_tr256.dense.weight', 'up_tr256.dense.bias', 'up_tr128.dense.weight', 'up_tr128.dense.bias', 'up_tr64.dense.weight', 'up_tr64.dense.bias', 'out_tr.final_conv_pp.weight', 'out_tr.final_conv_pp.bias'], unexpected_keys=['out_tr.final_conv.weight', 'out_tr.final_conv.bias'])
